# %% [markdown]
# # SPOTIFY SONGS ANALYSIS

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %% [markdown]
# **Loading Dataset**

# %%
df = pd.read_csv(r'C:\Users\Kirti Bohra\Downloads\universal_top_spotify_songs.csv')

# %% [markdown]
# **Understanding the dataset**

# %%
df.shape
# Out:
# (646053, 25)

# %%
df.head(10)
# Out:
#                spotify_id                                      name  \
# 0  2GxrNKugF82CnoRFbQfzPf                i like the way you kiss me
# 1  0AjmK0Eai4zGrLaJwPvrDp                                 Too Sweet
# 2  6XjDF6nds4DE2BBbagZol6                                 Gata Only
# 3  3xkHsmpQCBMytMJNiDf3Ii                          Beautiful Things
# 4  3qhlB30KknSejmIvZZLjOD                          End of Beginning
# 5  51ZQ1vr10ffzbwIjDCwqm4  we can't be friends (wait for your love)
# 6  2tudvzsrR56uom6smgOcSf                                 Like That
# 7  3rUGC1vUpkDG9CZFHMur1t                                    greedy
# 8  17phhZDn6oGtzMe56NuWvj                              Lose Control
# 9  7wLShogStyDeZvL0a6daN5                            TEXAS HOLD 'EM
#
#                                 artists  daily_rank  daily_movement  \
# 0                               Artemas           1               0
# 1                                Hozier           2               0
# 2                   FloyyMenor, Cris Mj           3               2
# 3                          Benson Boone           4              -1
# 4                                   Djo           5              -1
# 5                         Ariana Grande           6               0
# 6  Future, Metro Boomin, Kendrick Lamar           7               0
# 7                            Tate McRae           8               0
# 8                           Teddy Swims           9               0
# 9                               Beyoncé          10               2
#
#    weekly_movement country snapshot_date  popularity  is_explicit  ...  key  \
# 0                1     NaN    13-04-2024          97        False  ...   11
# 1                1     NaN    13-04-2024          85        False  ...   10
# 2                4     NaN    13-04-2024          96         True  ...    8
# 3               -3     NaN    13-04-2024          80        False  ...   10
# 4               -1     NaN    13-04-2024          99        False  ...    2
# 5               -1     NaN    13-04-2024          95        False  ...    5
# 6               -1     NaN    13-04-2024          95         True  ...   11
# 7                0     NaN    13-04-2024          96         True  ...    6
# 8                1     NaN    13-04-2024          93        False  ...    9
# 9               -1     NaN    13-04-2024          86         True  ...    2
#
#   loudness mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   -4.263    1       0.0447      0.000938          0.010600    0.0826
# 1   -5.505    1       0.0412      0.029500          0.000809    0.0398
# 2   -8.472    0       0.0509      0.446000          0.000024    0.0899
# 3   -5.692    1       0.0603      0.151000          0.000000    0.1400
# 4   -7.643    1       0.0584      0.035100          0.002590    0.0707
# 5   -8.305    1       0.0447      0.065700          0.000032    0.0751
# 6   -4.670    0       0.2310      0.007090          0.000013    0.1190
# 7   -3.180    0       0.0319      0.256000          0.000000    0.1140
# 8   -4.409    1       0.0337      0.199000          0.000019    0.1040
# 9   -6.549    1       0.0780      0.582000          0.000000    0.1580
#
#    valence    tempo  time_signature
# 0    0.747  151.647               4
# 1    0.934  117.038               4
# 2    0.669   99.986               4
# 3    0.219  105.029               3
# 4    0.912  159.982               4
# 5    0.287  115.830               4
# 6    0.312  162.012               4
# 7    0.844  111.018               1
# 8    0.242  159.920               3
# 9    0.375  110.012               4
#
# [10 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646053 entries, 0 to 646052
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   spotify_id          646053 non-null  object
#  1   name                646028 non-null  object
#  2   artists             646028 non-null  object
#  3   daily_rank          646053 non-null  int64
#  4   daily_movement      646053 non-null  int64
#  5   weekly_movement     646053 non-null  int64
#  6   country             637246 non-null  object
#  7   snapshot_date       646053 non-null  object
#  8   popularity          646053 non-null  int64
#  9   is_explicit         646053 non-null  bool
#  10  duration_ms         646053 non-null  int64
#  11  album_name          645806 non-null  object
#  12  album_release_date  645806 non-null  object
#  13  danceability        646053 non-null  float64
#  14  energy              646053 non-null  float64
#  15  key                 646053 non-null  int64
#  16  loudness            646053 non-null  float64
#  17  mode                646053 non-null  int64
#  18  speechiness         646053 non-null  float64
#  19  acousticness        646053 non-null  float64
#  20  instrumentalness    646053 non-null  float64
#  21  liveness            646053 non-null  float64
#  22  valence             646053 non-null  float64
#  23  tempo               646053 non-null  float64
#  24  time_signature      646053 non-null  int64
# dtypes: bool(1), float64(9), int64(8), object(7)
# memory usage: 118.9+ MB

# %%
df.columns
# Out:
# Index(['spotify_id', 'name', 'artists', 'daily_rank', 'daily_movement',
#        'weekly_movement', 'country', 'snapshot_date', 'popularity',
#        'is_explicit', 'duration_ms', 'album_name', 'album_release_date',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature'],
#       dtype='object')

# %%
df.describe()
# Out:
#           daily_rank  daily_movement  weekly_movement     popularity  \
# count  646053.000000   646053.000000    646053.000000  646053.000000
# mean       25.482276        0.931273         2.951131      77.562859
# std        14.426652        7.035179        12.209179      15.977099
# min         1.000000      -49.000000       -49.000000       0.000000
# 25%        13.000000       -1.000000        -3.000000      66.000000
# 50%        25.000000        0.000000         0.000000      82.000000
# 75%        38.000000        2.000000         5.000000      90.000000
# max        50.000000       49.000000        49.000000     100.000000
#
#          duration_ms   danceability         energy            key  \
# count  646053.000000  646053.000000  646053.000000  646053.000000
# mean   193386.765561       0.680774       0.648178       5.403233
# std     50476.903639       0.139778       0.163246       3.506189
# min         0.000000       0.000000       0.001890       0.000000
# 25%    161481.000000       0.582000       0.545000       2.000000
# 50%    186000.000000       0.699000       0.669000       6.000000
# 75%    218293.000000       0.787000       0.763000       8.000000
# max    939666.000000       0.988000       0.997000      11.000000
#
#             loudness           mode    speechiness   acousticness  \
# count  646053.000000  646053.000000  646053.000000  646053.000000
# mean       -6.540452       0.530679       0.097748       0.281743
# std         2.651172       0.499058       0.092102       0.258364
# min       -31.356000       0.000000       0.000000       0.000008
# 25%        -7.908000       0.000000       0.039900       0.073900
# 50%        -6.182000       1.000000       0.059000       0.188000
# 75%        -4.772000       1.000000       0.115000       0.442000
# max         3.233000       1.000000       0.921000       0.996000
#
#        instrumentalness       liveness        valence          tempo  \
# count     646053.000000  646053.000000  646053.000000  646053.000000
# mean           0.016499       0.175835       0.537532     122.544578
# std            0.088753       0.129273       0.229450      28.524114
# min            0.000000       0.015400       0.000000       0.000000
# 25%            0.000000       0.097500       0.361000      99.974000
# 50%            0.000001       0.121000       0.533000     119.962000
# 75%            0.000076       0.218000       0.725000     141.901000
# max            0.974000       0.978000       0.992000     217.969000
#
#        time_signature
# count   646053.000000
# mean         3.891998
# std          0.441786
# min          0.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          5.000000

# %% [markdown]
# **Checking missing values**

# %%
df.isnull().sum()/646053*100
# Out:
# spotify_id            0.000000
# name                  0.003870
# artists               0.003870
# daily_rank            0.000000
# daily_movement        0.000000
# weekly_movement       0.000000
# country               1.363201
# snapshot_date         0.000000
# popularity            0.000000
# is_explicit           0.000000
# duration_ms           0.000000
# album_name            0.038232
# album_release_date    0.038232
# danceability          0.000000
# energy                0.000000
# key                   0.000000
# loudness              0.000000
# mode                  0.000000
# speechiness           0.000000
# acousticness          0.000000
# instrumentalness      0.000000
# liveness              0.000000
# valence               0.000000
# tempo                 0.000000
# time_signature        0.000000
# dtype: float64

# %% [markdown]
# **Filling missing values**

# %%
df["country"] = df["country"].fillna("Global")

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# spotify_id            0
# name                  0
# artists               0
# daily_rank            0
# daily_movement        0
# weekly_movement       0
# country               0
# snapshot_date         0
# popularity            0
# is_explicit           0
# duration_ms           0
# album_name            0
# album_release_date    0
# danceability          0
# energy                0
# key                   0
# loudness              0
# mode                  0
# speechiness           0
# acousticness          0
# instrumentalness      0
# liveness              0
# valence               0
# tempo                 0
# time_signature        0
# dtype: int64

# %% [markdown]
# ## Top Trending Songs Analysis

# %% [markdown]
# **Top 10 popular songs over the last 2 months**

# %%
# Filter the dataset for the specified date range (1st January 2024 to 1st March 2024)
start_date = pd.Timestamp(2024, 1, 1)
end_date = pd.Timestamp(2024, 3, 15)
filtered_data = df[(df['snapshot_date'] >= start_date) & (df['snapshot_date'] < end_date)]

# Group by song and calculate the mean popularity for each song
popularity_per_song = filtered_data.groupby('name')['popularity'].mean()

# Sort the songs by popularity in descending order and select the top 10
top_10_songs = popularity_per_song.nlargest(10).reset_index()['name']

print("Top 10 Popular Songs from 1st January 2024 to 15th March 2024:")
print(top_10_songs)
# Out:
# Top 10 Popular Songs from 1st January 2024 to 15th March 2024:
# 0      All I Want for Christmas Is You
# 1                               greedy
# 2                         Cruel Summer
# 3                My Love Mine All Mine
# 4                          Lovin On Me
# 5    Rockin' Around The Christmas Tree
# 6                            La Diabla
# 7                         Stick Season
# 8                        Santa Tell Me
# 9                                 LUNA
# Name: name, dtype: object

# %% [markdown]
# **How does the popularity of songs vary over time?**

# %%
df['snapshot_date'] = pd.to_datetime(df['snapshot_date'])

popularity_over_time = df.groupby('snapshot_date')['popularity'].mean()
# Out:
# C:\Users\Kirti Bohra\AppData\Local\Temp\ipykernel_19276\1651035025.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['snapshot_date'] = pd.to_datetime(df['snapshot_date'])

# %%
plt.figure(figsize=(12, 6))
popularity_over_time.plot(color='b')
plt.title('Popularity of Songs Over Time', fontweight='bold')
plt.xlabel('Date', fontweight='bold')
plt.ylabel('Popularity (Mean)', fontweight='bold')
plt.grid(True)
plt.show()

# %% [markdown]
# **How does the daily rank of songs change over the week?**

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='snapshot_date', y='daily_rank', data=df, color='b')
plt.title('Daily Rank Trend Over Time', fontweight='bold')
plt.xlabel('Snapshot Date', fontweight='bold')
plt.ylabel('Daily Rank', fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Count plot showing explicit vs. non-explicit songs**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='is_explicit', data=df, palette=['#432371',"#FAAE7B"])
plt.xlabel('Explicit', fontweight='bold')
plt.ylabel('Count', fontweight='bold')
plt.title('Explicit vs. Non-Explicit Songs', fontweight='bold')
plt.show()

# %% [markdown]
# **Bar plot showing the top 10 most common keys**

# %%
top_10_keys = df['key'].value_counts().head(10)
plt.figure(figsize=(10, 6))
top_10_keys.plot(kind='bar', color='blue')
plt.xlabel('Key', fontweight='bold')
plt.ylabel('Count', fontweight='bold')
plt.title('Top 10 Most Common Keys', fontweight='bold')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **Relationship between danceability and energy**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='danceability', y='energy', data=df, color='g')
plt.xlabel('Danceability', fontweight='bold')
plt.ylabel('Energy', fontweight='bold')
plt.title('Relationship between Danceability and Energy', fontweight='bold')
plt.show()
